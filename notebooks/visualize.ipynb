# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
df_path = "../results/summary.csv"
df = pd.read_csv(df_path)
df
# Out:
#     dataset  method  trial  num_docs  num_queries  index_time_s      qps  \
# 0  nfcorpus  splade      0      3633          323        3.4649  14.8623
#
#     NDCG@1  NDCG@10  NDCG@100
# 0  0.48297  0.34731   0.30777
